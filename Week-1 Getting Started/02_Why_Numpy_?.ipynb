# %% [markdown]
# <a href="https://colab.research.google.com/github/someshsingh22/CTE-Intro-To-Machine-Learning/blob/master/Week-1%20Getting%20Started/02_Why_Numpy_%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMPORTS

# %% [markdown]
# Now we introduce you to one of the most important libraries for data science and machine learning for python : **numpy**
# NumPy provides an efficient storage and better way handling of the data for mathematical operations using simple API’s, the benefit of which far out-weights writing your own.

# %%
import numpy as np

# %% [markdown]
# ## SPEED ...
# Numpy arrays are densely packed arrays of homogeneous type unlike array of objects as in Python list. So, you get the benefits of locality of reference and it makes your code faster (as much as around 20x with two array of $10^7$ elements) Following code snippets will show you it happening.

# %% [markdown]
# ### Functions to compare *numpy* and *regular python* way

# %%
# List_add is a function that adds a two list of given size
def list_add(size):
    added_python_list=[]
    python_list1 = [i for i in range(size)]
    python_list2 = [2*i for i in range(size)]
    for i in range(len(python_list1)):
        added_python_list.append(python_list1[i] + python_list2[i])

# np_add adds two numpy arrays of a given size
def np_add(size):
    numpy_array1 = np.arange(0,size,1)
    numpy_array2 = 2*numpy_array1
    added_numpy_array = numpy_array1 + numpy_array2

# %% [markdown]
# ### Function to return a list of time intervals for sizes varying from $2^{10}$ to $2^{23}$

# %%
# time is a library used to create time variables
import time

# time_list is a function to return a numpy array that appends time taken by function calls
start,end=10,23.2535
x=np.linspace(start,end,80)
def time_list(function,start=start,end=end):
    time_taken=[]
    for i in x:
        start=time.time()
        function(int(2**i))
        time_taken.append(time.time()-start)
    return (np.asarray(time_taken))*1000

# %% [markdown]
# ### Notice the difference in time intervals for a range of ~$10^7$ elements (takes ~40s)

# %%
# %%time
print("start : ",2**start)
print("end : ",int(2**(end)))
list_time=time_list(list_add)
np_time  =time_list(np_add)
print("time for size of {} =\n\t\t List : {} ms\n\t\t Numpy: {} ms".format(2**(end),int(list_time[-1]),int(np_time[-1])))
# Out:
# start :  1024
# end :  10000023
# time for size of 10000023.121950408 =
# 		 List : 2230 ms
# 		 Numpy: 96 ms
# CPU times: user 16.5 s, sys: 3.24 s, total: 19.7 s
# Wall time: 19.7 s

# %% [markdown]
# ### Plot of time intervals Numpy vs Python List

# %% [markdown]
# Plotting techniques using matplotlib and seaborn will be explained later

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["animation.html"] = "jshtml"
import matplotlib.animation as animation
fig, ax = plt.subplots()
line1, = ax.plot(x, list_time, color = "red", label="list_time")
line2, = ax.plot(x, np_time, color = "green",label="numpy time")
def update(num, x, list_time, np_time, line1, line2):
    line1.set_data(x[:num], list_time[:num])
    line2.set_data(x[:num], np_time[:num])
    return [line1,line2]

ax.legend()
ani = animation.FuncAnimation(fig, update, len(x), fargs=[x, list_time, np_time, line1, line2],
                  interval=int(len(x)), blit=True)

ani
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img8a1ee1db9f74446ab66d92b096b1bcc0">
#     <br>
#     <input id="_anim_slider8a1ee1db9f74446ab66d92b096b1bcc0" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim8a1ee1db9f74446ab66d92b096b1bcc0.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim8a1ee1db9f74446ab66d92b096b1bcc0.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim8a1ee1db9f74446ab66d92b096b1bcc0.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim8a1ee1db9f74446ab66d92b096b1bcc0.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim8a1ee1db9f74446ab66d92b096b1bcc0.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim8a1ee1db9f74446ab66d92b096b1bcc0.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim8a1ee1db9f74446ab66d92b096b1bcc0.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim8a1ee1db9f74446ab66d92b096b1bcc0.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim8a1ee1db9f74446ab66d92b096b1bcc0.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim8a1ee1db9f74446ab66d92b096b1bcc0.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select8a1ee1db9f74446ab66d92b096b1bcc0" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img8a1ee1db9f74446ab66d92b096b1bcc0";
#     var slider_id = "_anim_slider8a1ee1db9f74446ab66d92b096b1bcc0";
#     var loop_select_id = "_anim_loop_select8a1ee1db9f74446ab66d92b096b1bcc0";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAAGVFJREFUeJzt3WtwVOUdx/HfJuEyjJE2QEjYTbPQ\
# zUDIbYFwsa0gzSxgWhOBlkERYmNFqFOUVigzVod0qkmpFmxRNFPQ0FqB8ZaOQGBaiANWDAtmLMRp\
# dyiZJjGNuRatIhCevnDcEUm4SXL2Id/PK3J2z9n/rp79zp49u+syxhgBAGCZKKcHAADgShAwAICV\
# CBgAwEoEDABgJQIGALASAQMAWImAAQCsRMAAAFYiYAAAKxEwAICVCBgAwEoEDABgJQIGALASAQMA\
# WImAAQCsRMAAAFYiYAAAKxEwAICVCBgAwEoEDABgJQIGALASAQMAWImAAQCsRMAAAFYiYAAAKxEw\
# AICVCBgAwEoEDABgJQIGALASAQMAWImAAQCsRMAAAFYiYAAAKxEwAICVYpweoKcMHTpUXq/X6TEA\
# wCq1tbVqaWlxeoxLcs0GzOv1KhgMOj0GAFglOzvb6REuGYcQAQBWImAAACsRMACAla7Z98AARL7T\
# p0+rvr5eJ0+edHqUPmfgwIHyeDzq16+f06NcMQIGwDH19fWKjY2V1+uVy+Vyepw+wxij1tZW1dfX\
# a+TIkU6Pc8U4hAjAMSdPntSQIUOIVy9zuVwaMmSI9a98CRgARxEvZ1wLjzsBA9CnXXfddZKk9957\
# T9/73ve6vV5HR4eeeuqpC26rtrZWf/rTn8J/B4NBLVu27OoMivMQMACQNGLECL344ovdXn4lAcvO\
# ztZvf/vbqzYjzkXAAECfxic9PV2SdPToUU2aNEl+v1+ZmZkKhUJatWqVjh07Jr/frxUrVnS5jVWr\
# Vmnfvn3y+/1au3atKisr9d3vfleStHr1ahUUFOjGG29UcnKyXn75Za1cuVIZGRmaNWuWTp8+LUk6\
# dOiQpk2bpgkTJmjmzJlqbGzsnQfAQpyFCCAy3H+/VF19dbfp90vr1l32ak8//bTuu+8+LViwQKdO\
# nVJnZ6dKSkp05MgRVV9gxpKSEj322GN67bXXJEmVlZXnXH7s2DHt3btXNTU1uuGGG/TSSy9pzZo1\
# mj17trZv367vfOc7+vGPf6zy8nINGzZMW7du1YMPPqhNmzZd9n3oCwgYAHzBDTfcoEceeUT19fWa\
# M2eOUlJSrsp2b775ZvXr108ZGRnq7OzUrFmzJEkZGRmqra3VP/7xDx05ckSBQECS1NnZqcTExKty\
# 29ciAgYgMlzBK6Wecvvtt2vy5Mnavn27cnNz9cwzz2jUqFFfersDBgyQJEVFRalfv37hMwGjoqJ0\
# 5swZGWOUlpamN99880vfVl/Ae2AA8AX/+te/NGrUKC1btkz5+fl65513FBsbqw8++OCC613KdS5k\
# 9OjRam5uDgfs9OnTOnr06BVv71pHwADgC7Zt26b09HT5/X4dOXJEixYt0pAhQ/TNb35T6enp3Z7E\
# kZmZqejoaGVlZWnt2rWXfbv9+/fXiy++qJ/97GfKysqS3+/X3/72ty97d65ZLmOMcXqInpCdnc3v\
# gQER7t1331VqaqrTY/RZXT3+Nj138goMAGAlTuIAgMv097//XQsXLjxn2YABA/TWW285NFHfRMAA\
# 4DJlZGRc8PNg6B0cQgQAWImAAQCsRMAAAFYiYAAQYSorK8/5/NfTTz+tzZs3OzhRZOIkDgCIMJWV\
# lbruuuv0jW98Q5K0ZMkShyeKTD36Cqyurk7Tp0/X2LFjlZaWpieeeEKS1NbWpkAgoJSUFAUCAbW3\
# t0uSjDFatmyZfD6fMjMzdfjw4fC2ysrKlJKSopSUFJWVlfXk2AD6iNraWqWmpuruu+9WWlqaZsyY\
# oY8//liSdNNNN4U/0NvS0iKv1ytJeu6553TrrbcqEAjI6/Vq/fr1+s1vfqNx48Zpy

# %% [markdown]
# ## MEMORY ...
# The NumPy arrays takes significantly less amount of memory as compared to python lists. It also provides a mechanism of specifying the data types of the contents, which allows further optimisation of the code.

# %%
import numpy as np
import sys

py_arr = [1,2,3,4,5,6]
numpy_arr = np.array([1,2,3,4,5,6])

sizeof_py_arr = sys.getsizeof(1) * len(py_arr)           # Size = 168
sizeof_numpy_arr = numpy_arr.itemsize * numpy_arr.size   # Size = 48
print("Python List consumes",sizeof_py_arr,"\nWhile NumPy array consumes",sizeof_numpy_arr)
# Out:
# Python List consumes 168
# While NumPy array consumes 48

# %% [markdown]
# This is very efficient considering you generally deal with arrays of millions of elements.
# It’s possible to do further optimisation on the NumPy arrays if we know the maximum number of individual data we’re planning to have. Suppose you know that your data is in form of integers, all less than 255 (NumPy initially assumes 8bytes) you can store them all in one byte = 8bits

# %%
py_arr = [1,2,3,4,5,6]
sizeof_py_arr = sys.getsizeof(1) * len(py_arr)           # Size = 168

numpy_arr = np.array([1,2,3,4,5,6], dtype = np.int8)
sizeof_numpy_arr = numpy_arr.itemsize * numpy_arr.size   # Size = 6
print("Python List consumes",sizeof_py_arr,"\nWhile NumPy array consumes",sizeof_numpy_arr)
# Out:
# Python List consumes 168
# While NumPy array consumes 6

# %% [markdown]
# Also NumPy features a lot of other features like mean,median,where,count nonzero that help you to understand your data better and faster. Visit the documentaion at :[Documentation](https://docs.scipy.org/doc/numpy/).
# Refer to the bottom of this page for other sources : [Week1 Resources](https://github.com/someshsingh22/CTE-Intro-To-Machine-Learning/tree/master/Week-1%20Getting%20Started)
#
# ### Read Alex's Answer, infact read all his answer to understand Python in depth!
# https://stackoverflow.com/questions/993984/why-numpy-instead-of-python-lists
